# %% [markdown]
# <a href="https://colab.research.google.com/github/rskrisel/tf-idf/blob/main/TF_IDF_with_Scikit_Learn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This curriculum is copied from Melanie Walsh's *Introduction to Cultural Analytics & Python*. A few code updates were made to reflect the newest versions of Scikit-learn and Pandas.
#
# The dataset for the curriculum is available [here](https://melaniewalsh.github.io/Intro-Cultural-Analytics/_downloads/64e2547e2d86c20cc2a74f660143cfeb/US_Inaugural_Addresses.zip).

# %% [markdown]
# # TF-IDF with Scikit-Learn

# %% [markdown]
# In the previous lesson, we learned about a text analysis method called *term frequency–inverse document frequency*, often abbreviated *tf-idf*. Tf-idf is a method that tries to identify the most distinctively frequent or significant words in a document. We specifically learned how to calculate tf-idf scores using word frequencies per page—or "extracted features"—made available by the HathiTrust Digital Library.
#
# In this lesson, we're going to learn how to calculate tf-idf scores using a collection of plain text (.txt) files and the Python library scikit-learn, which has a quick and nifty module called [TfidfVectorizer](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html).
#
# In this lesson, we will cover how to:
# - Calculate and normalize tf-idf scores for U.S. Inaugural Addresses with scikit-learn

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### U.S. Inaugural Addresses
#
# <blockquote class="epigraph" style=" padding: 10px">
#
# This is the meaning of our liberty and our creed; why men and women and children of every race and every faith can join in celebration across this magnificent Mall, and why a man whose father less than 60 years ago might not have been served at a local restaurant can now stand before you to take a most sacred oath.  So let us mark this day with remembrance of who we are and how far we have traveled.
# <p class ="attribution">—Barack Obama, Inaugural Presidential Address, January 2009
#     </p>
#
# </blockquote>

# %% [markdown]
# During Barack Obama's Inaugural Address in January 2009, he mentioned "women" four different times, including in the passage quoted above. How distinctive is Obama's inclusion of women in this address compared to all other U.S. Presidents? This is one of the questions that we're going to try to answer with tf-idf.

# %% [markdown]
# ## Breaking Down the TF-IDF Formula

# %% [markdown]
# But first, let's quickly discuss the tf-idf formula. The idea is pretty simple.

# %% [markdown]
# **tf-idf = term_frequency * inverse_document_frequency**

# %% [markdown]
# **term_frequency** = number of times a given term appears in document

# %% [markdown]
# **inverse_document_frequency** = log(total number of documents / number of documents with term) + 1**\***

# %% [markdown]
# You take the number of times a term occurs in a document (term frequency). Then you take the number of documents in which the same term occurs at least once divided by the total number of documents (document frequency), and you flip that fraction on its head (inverse document frequency). Then you multiply the two numbers together (term_frequency * inverse_document_frequency).
#
# The reason we take the *inverse*, or flipped fraction, of document frequency is to boost the rarer words that occur in relatively few documents. Think about the inverse document frequency for the word "said" vs the word "pigeon." The term "said" appears in 13 (document frequency) of 14 (total documents) *Lost in the City* stories (14 / 13 --> a smaller inverse document frequency) while the term "pigeons" only occurs in 2 (document frequency) of the 14 stories (total documents) (14 / 2 --> a bigger inverse document frequency, a bigger tf-idf boost).

# %% [markdown]
# *There are a bunch of slightly different ways that you can calculate inverse document frequency. The version of idf that we're going to use is the [scikit-learn default](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html#sklearn.feature_extraction.text.TfidfTransformer), which uses "smoothing" aka it adds a "1" to the numerator and denominator:

# %% [markdown]
# **inverse_document_frequency**  = log((1 + total_number_of_documents) / (number_of_documents_with_term +1)) + 1

# %% [markdown]
# <div class="margin sidebar" style=" padding: 10px">
#
# > If smooth_idf=True (the default), the constant “1” is added to the numerator and denominator of the idf as if an extra document was seen containing every term in the collection exactly once, which prevents zero divisions: idf(t) = log [ (1 + n) / (1 + df(t)) ] + 1.
# > -[scikit-learn documentation](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html#sklearn.feature_extraction.text.TfidfTransformer)
#
# </div>

# %% [markdown]
# ## TF-IDF with scikit-learn

# %% [markdown]
# [scikit-learn](https://scikit-learn.org/stable/index.html), imported as `sklearn`, is a popular Python library for machine learning approaches such as clustering, classification, and regression. Though we're not doing any machine learning in this lesson, we're nevertheless going to use scikit-learn's `TfidfVectorizer` and `CountVectorizer`.

# %% [markdown]
# If you are working in Colab, you don't need to install scikit-learn. If you are working in a different python environment, you might need to run the code below.

# %%
# !pip install sklearn

# %% [markdown]
# Import necessary modules and libraries

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
pd.options.display.max_rows = 600
from pathlib import Path
import glob

# %% [markdown]
# We're also going to import `pandas` and change its default display setting. And we're going to import two libraries that will help us work with files and the file system: [`pathlib`](https://docs.python.org/3/library/pathlib.html##basic-use) and [`glob`](https://docs.python.org/3/library/glob.html).

# %% [markdown]
# #### Import data from the GitHub repository
#
# Start by cloning the repository:

# %%
# !git clone https://github.com/rskrisel/tf-idf
# Out:
# Cloning into 'tf-idf'...
# remote: Enumerating objects: 76, done.
# remote: Counting objects: 100% (76/76), done.
# remote: Compressing objects: 100% (73/73), done.
# remote: Total 76 (delta 4), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (76/76), 327.49 KiB | 3.64 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %% [markdown]
# Navigate to the cloned repository:

# %%
# %cd tf-idf/
# Out:
# /content/tf-idf

# %% [markdown]
# List the contents of the repository:

# %%
# %ls
# Out:
# README.md  TF-IDF-with-Scikit-Learn.ipynb  US_Inaugural_Addresses/

# %% [markdown]
# Read through the files within the `US_Inaugural_Addresses` directory:

# %%
text_files = glob.glob("US_Inaugural_Addresses/*.txt")

# %%
text_files
# Out:
# ['US_Inaugural_Addresses/26_harrison_1889.txt',
#  'US_Inaugural_Addresses/54_bush_george_w_2001.txt',
#  'US_Inaugural_Addresses/14_harrison_1841.txt',
#  'US_Inaugural_Addresses/04_jefferson_1801.txt',
#  'US_Inaugural_Addresses/47_nixon_1973.txt',
#  'US_Inaugural_Addresses/05_jefferson_1805.txt',
#  'US_Inaugural_Addresses/27_cleveland_1893.txt',
#  'US_Inaugural_Addresses/02_washington_1793.txt',
#  'US_Inaugural_Addresses/18_buchanan_1857.txt',
#  'US_Inaugural_Addresses/30_roosevelt_theodore_1905.txt',
#  'US_Inaugural_Addresses/31_taft_1909.txt',
#  'US_Inaugural_Addresses/42_eisenhower_1953.txt',
#  'US_Inaugural_Addresses/38_roosevelt_franklin_1937.txt',
#  'US_Inaugural_Addresses/13_van_buren_1837.txt',
#  'US_Inaugural_Addresses/24_garfield_1881.txt',
#  'US_Inaugural_Addresses/34_harding_1921.txt',
#  'US_Inaugural_Addresses/09_monroe_1821.txt',
#  'US_Inaugural_Addresses/46_nixon_1969.txt',
#  'US_Inaugural_Addresses/52_clinton_1993.txt',
#  'US_Inaugural_Addresses/01_washington_1789.txt',
#  'US_Inaugural_Addresses/15_polk_1845.txt',
#  'US_Inaugural_Addresses/43_eisenhower_1957.txt',
#  'US_Inaugural_Addresses/07_madison_1813.txt',
#  'US_Inaugural_Addresses/11_jackson_1829.txt',
#  'US_Inaugural_Addresses/48_carter_1977.txt',
#  'US_Inaugural_Addresses/56_obama_2009.txt',
#  'US_Inaugural_Addresses/28_mckinley_1897.txt',
#  'US_Inaugural_Addresses/36_hoover_1929.txt',
#  'US_Inaugural_Addresses/29_mckinley_1901.txt',
#  'US_Inaugural_Addresses/44_kennedy_1961.txt',
#  'US_Inaugural_Addresses/25_cleveland_1885.txt',
#  'US_Inaugural_Addresses/03_adams_john_1797.txt',
#  'US_Inaugural_Addresses/12_jackson_1833.txt',
#  'US_Inaugural_Addresses/53_clinton_1997.txt',
#  'US_Inaugural_Addresses/06_madison_1809.txt',
#  'US_Inaugural_Addresses/39_roosevelt_franklin_1941.txt',
#  'US_Inaugural_Addresses/10_adams_john_quincy_1825.txt',
#  'US_Inaugural_Addresses/40_roosevelt_franklin_1945.txt',
#  'US_Inaugural_Addresses/32_wilson_1913.txt',
#  'US_Inaugural_Addresses/08_monroe_1817.txt',
#  'US_Inaugural_Addresses/17_pierce_1853.txt',
#  'US_Inaugural_Addresses/57_obama_2013.txt',
#  'US_Inaugural_Addresses/50_reagan_1985.txt',
#  'US_Inaugural_Addresses/51_bush_george_h_w_1989.txt',
#  'US_Inaugural_Addresses/21_grant_1869.txt',
#  'US_Inaugural_Addresses/45_johnson_1965.txt',
#  'US_Inaugural_Addresses/23_hayes_1877.txt',
#  'US_Inaugural_Addresses/55_bush_george_w_2005.txt',
#  'US_Inaugural_Addresses/19_lincoln_1861.txt',
#  'US_Inaugural_Addresses/22_grant_1873.txt',
#  'US_Inaugural_Addresses/16_taylor_1849.txt',
#  'US_Inaugural_Addresses/20_lincoln_1865.txt',
#  'US_Inaugural_Addresses/35_coolidge_1925.txt',
#  'US_Inaugural_Addresses/49_reagan_1981.txt',
#  'US_Inaugural_Addresses/58_trump_2017.txt',
#  'US_Inaugural_Addresses/33_wilson_1917.txt',
#  'US_Inaugural_Addresses/37_roosevelt_franklin_1933.txt',
#  'US_Inaugural_Addresses/41_truman_1949.txt']

# %%
text_titles = [Path(text).stem for text in text_files]

# %%
text_titles
# Out:
# ['26_harrison_1889',
#  '54_bush_george_w_2001',
#  '14_harrison_1841',
#  '04_jefferson_1801',
#  '47_nixon_1973',
#  '05_jefferson_1805',
#  '27_cleveland_1893',
#  '02_washington_1793',
#  '18_buchanan_1857',
#  '30_roosevelt_theodore_1905',
#  '31_taft_1909',
#  '42_eisenhower_1953',
#  '38_roosevelt_franklin_1937',
#  '13_van_buren_1837',
#  '24_garfield_1881',
#  '34_harding_1921',
#  '09_monroe_1821',
#  '46_nixon_1969',
#  '52_clinton_1993',
#  '01_washington_1789',
#  '15_polk_1845',
#  '43_eisenhower_1957',
#  '07_madison_1813',
#  '11_jackson_1829',
#  '48_carter_1977',
#  '56_obama_2009',
#  '28_mckinley_1897',
#  '36_hoover_1929',
#  '29_mckinley_1901',
#  '44_kennedy_1961',
#  '25_cleveland_1885',
#  '03_adams_john_1797',
#  '12_jackson_1833',
#  '53_clinton_1997',
#  '06_madison_1809',
#  '39_roosevelt_franklin_1941',
#  '10_adams_john_quincy_1825',
#  '40_roosevelt_franklin_1945',
#  '32_wilson_1913',
#  '08_monroe_1817',
#  '17_pierce_1853',
#  '57_obama_2013',
#  '50_reagan_1985',
#  '51_bush_george_h_w_1989',
#  '21_grant_1869',
#  '45_johnson_1965',
#  '23_hayes_1877',
#  '55_bush_george_w_2005',
#  '19_lincoln_1861',
#  '22_grant_1873',
#  '16_taylor_1849',
#  '20_lincoln_1865',
#  '35_coolidge_1925',
#  '49_reagan_1981',
#  '58_trump_2017',
#  '33_wilson_1917',
#  '37_roosevelt_franklin_1933',
#  '41_truman_1949']

# %% [markdown]
# ## Calculate tf–idf

# %% [markdown]
# To calculate tf–idf scores for every word, we're going to use scikit-learn's [`TfidfVectorizer`](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html).
#
# When you initialize TfidfVectorizer, you can choose to set it with different parameters. These parameters will change the way you calculate tf–idf.

# %% [markdown]
# The recommended way to run `TfidfVectorizer` is with smoothing (`smooth_idf = True`) and normalization (`norm='l2'`) turned on. These parameters will better account for differences in text length, and overall produce more meaningful tf–idf scores. Smoothing and L2 normalization are actually the default settings for `TfidfVectorizer`, so to turn them on, you don't need to include any extra code at all.

# %% [markdown]
# Initialize TfidfVectorizer with desired parameters (default smoothing and normalization)

# %%
tfidf_vectorizer = TfidfVectorizer(input='filename', stop_words='english')

# %% [markdown]
# Run TfidfVectorizer on our `text_files`

# %%
tfidf_vector = tfidf_vectorizer.fit_transform(text_files)

# %%
type(tfidf_vector)
# Out:
# scipy.sparse._csr.csr_matrix

# %% [markdown]
# Make a DataFrame out of the resulting tf–idf vector, setting the "feature names" or words as columns and the titles as rows

# %%
tfidf_df = pd.DataFrame(tfidf_vector.toarray(), index=text_titles, columns=tfidf_vectorizer.get_feature_names_out())

# %% [markdown]
# Add column for document frequency aka number of times word appears in all documents

# %%
tfidf_df.loc['00_Document Frequency'] = (tfidf_df > 0).sum()

# %%
tfidf_slice = tfidf_df[['government', 'borders', 'people', 'obama', 'war', 'honor','foreign', 'men', 'women', 'children']]
tfidf_slice.sort_index().round(decimals=2)
# Out:
#                             government  borders  people  obama    war  honor  \
# 00_Document Frequency            53.00     5.00   56.00   3.00  45.00  32.00
# 01_washington_1789                0.11     0.00    0.05   0.00   0.00   0.00
# 02_washington_1793                0.06     0.00    0.05   0.00   0.00   0.08
# 03_adams_john_1797                0.16     0.00    0.19   0.00   0.01   0.10
# 04_jefferson_1801                 0.16     0.00    0.01   0.00   0.01   0.04
# 05_jefferson_1805                 0.03     0.00    0.00   0.00   0.04   0.00
# 06_madison_1809                   0.00     0.00    0.02   0.00   0.02   0.05
# 07_madison_1813                   0.04     0.00    0.04   0.00   0.25   0.02
# 08_monroe_1817                    0.17     0.00    0.11   0.00   0.09   0.01
# 09_monroe_1821                    0.08     0.00    0.06   0.00   0.11   0.02
# 10_adams_john_quincy_1825         0.15     0.00    0.06   0.00   0.05   0.01
# 11_jackson_1829                   0.10     0.00    0.06   0.00   0.02   0.02
# 12_jackson_1833                   0.21     0.00    0.14   0.00   0.00   0.00
# 13_van_buren_1837                 0.12     0.00    0.14   0.00   0.02   0.02
# 14_harrison_1841                  0.14     0.00    0.14   0.00   0.01   0.02
# 15_polk_1845                      0.26     0.00    0.08   0.00   0.03   0.01
# 16_taylor_1849                    0.12     0.00    0.05   0.00   0.00   0.02
# 17_pierce_1853                    0.08     0.00    0.05   0.00   0.00   0.02
# 18_buchanan_1857                  0.12     0.00    0.11   0.00   0.08   0.01
# 19_lincoln_1861                   0.12     0.00    0.13   0.00   0.02   0.00
# 20_lincoln_1865                   0.02     0.00    0.00   0.00   0.27   0.00
# 21_grant_1869                     0.05     0.00    0.03   0.00   0.02   0.05
# 22_grant_1873                     0.06     0.00    0.10   0.00   0.05   0.02
# 23_hayes_1877                     0.17     0.00    0.08   0.00   0.00   0.00
# 24_garfield_1881                  0.19     0.00    0.16   0.00   0.05   0.00
# 25_cleveland_1885                 0.21     0.00    0.21   0.00   0.00   0.00
# 26_harrison_1889                  0.06     0.00    0.17   0.00   0.02   0.03
# 27_cleveland_1893                 0.15     0.00    0.22   0.00   0.00   0.00
# 28_mckinley_1897                  0.16     0.00    0.16   0.00   0.05   0.03
# 29_mckinley_1901                  0.15     0.00    0.12   0.00   0.08   0.04
# 30_roosevelt_theodore_1905        0.05     0.00    0.10   0.00   0.00   0.00
# 31_taft_1909                      0.12     0.00    0.03   0.00   0.03   0.01
# 32_wilson_1913                    0.11     0.00    0.02   0.00   0.00   0.00
# 33_wilson_1917                    0.00     0.00    0.08   0.00   0.07   0.00
# 34_harding_1921                   0.08     0.00    0.05   0.00   0.12   0.00
# 35_coolidge_1925                  0.10     0.00    0.10   0.00   0.02   0.01
# 36_hoover_1929                    0.20     0.04    0.10   0.00   0.01   0.00
# 37_roosevelt_franklin_1933        0.03     0.00    0.08   0.00   0.02   0.02
# 38_roosevelt_franklin_1937        0.18     0.03    0.12   0.00   0.01   0.00
# 39_roosevelt_franklin_1941        0.05     0.00    0.08   0.00   0.00   0.00
# 40_roosevelt_franklin_1945        0.00     0.00    0.02   0.00   0.05   0.03
# 41_truman_1949                    0.03     0.00    0.10   0.00   0.02   0.01
# 42_eisenhower_1953                0.01     0.00    0.10   0.00   0.04   0.03
# 43_eisenhower_1957                0.00     0.00    0.10   0.00   0.01   0.05
# 44_kennedy_1961                   0.00     0.00    0.01   0.00   0.06   0.00
# 45_johnson_1965                   0.01     0.00    0.11   0.00   0.01   0.00
# 46_nixon_1969                     0.05     0.00    0.13   0.00   0.03   0.03
# 47_nixon_1973                     0.10     0.00    0.06   0.00   0.03   0.01
# 48_carter_1977                    0.06     0.00    0.08   0.00   0.02   0.00
# 49_reagan_1981                    0.16     0.00    0.08   0.00   0.01   0.00
# 50_reagan_1985                    0.16     0.00    0.14   0.00   0.01   0.01
# 51_bush_george_h_w_1989           0.05     0.00    0.06   0.00   0.03   0.00
# 52_clinton_1993                   0.05     0.00    0.13   0.00   0.03   0.00
# 53_clinton_1997                   0.09     0.00    0.09   0.00   0.01   0.00
# 54_bush_george_w_2001             0.05     0.00    0.01   0.00   0.01   0.00
# 55_bush_george_w_2005             0.03     0.06    0.05   0.00   0.00   0.04
# 56_obama_2009                     0.03     0.03    0.07   0.03   0.02   0.01
# 57_obama_2013                     0.04     0.00    0.11   0.04   0.04   0.00
# 58_trump_2017                     0.04     0.11    0.11   0.12   0.00   0.00
#
#                             foreign    men  women  children
# 00_Document Frequency         32.00  47.00  15.00     22.00
# 01_washington_1789             0.00   0.02   0.00      0.00
# 02_washington_1793             0.00   0.00   0.00      0.00
# 03_adams_john_1797             0.12   0.04   0.00      0.00
# 04_jefferson_1801              0.00   0.04   0.00      0.00
# 05_jefferson_1805              0.06   0.01   0.00      0.02
# 06_madison_1809                0.05   0.00   0.00      0.00
# 07_madison_1813                0.02   0.00   0.00      0.00
# 08_monroe_1817                 0.10   0.04   0.00      0.00
# 09_monroe_1821                 0.04   0.01   0.00      0.01
# 10_adams_john_quincy_1825      0.08   0.03   0.00      0.00
# 11_jackson_1829                0.07   0.02   0.00      0.00
# 12_jackson_1833                0.02   0.00   0.00      0.00
# 13_van_buren_1837              0.06   0.02   0.00      0.01
# 14_harrison_1841               0.03   0.03   0.00      0.00
# 15_polk_1845                   0.09   0.02   0.00      0.01
# 16_taylor_1849                 0.05   0.00   0.00      0.00
# 17_pierce_1853                 0.04   0.01   0.00      0.03
# 18_buchanan_1857               0.04   0.03   0.00      0.05
# 19_lincoln_1861                0.02   0.00   0.00      0.00
# 20_lincoln_1865                0.00   0.04   0.00      0.00
# 21_grant_1869                  0.05   0.02   0.00      0.00
# 22_grant_1873                  0.00   0.00   0.00      0.00
# 23_hayes_1877                  0.04   0.02   0.00      0.00
# 24_garfield_1881               0.00   0.01   0.00      0.04
# 25_cleveland_1885              0.05   0.01   0.00      0.00
# 26_harrison_1889               0.01   0.04   0.00      0.00
# 27_cleveland_1893              0.00   0.04   0.00      0.00
# 28_mckinley_1897               0.06   0.02   0.00      0.00
# 29_mckinley_1901               0.01   0.01   0.00      0.00
# 30_roosevelt_theodore_1905     0.00   0.08   0.00      0.10
# 31_taft_1909                   0.03   0.03   0.00      0.00
# 32_wilson_1913                 0.00   0.14   0.10      0.06
# 33_wilson_1917                 0.00   0.05   0.00      0.00
# 34_harding_1921                0.00   0.01   0.00      0.00
# 35_coolidge_1925               0.02   0.02   0.02      0.00
# 36_hoover_1929                 0.01   0.03   0.03      0.01
# 37_roosevelt_franklin_1933     0.03   0.02   0.00      0.00
# 38_roosevelt_franklin_1937     0.00   0.10   0.07      0.02
# 39_roosevelt_franklin_1941     0.00   0.07   0.03      0.00
# 40_roosevelt_franklin_1945     0.00   0.10   0.05      0.04
# 41_truman_1949                 0.01   0.06   0.00      0.00
# 42_eisenhower_1953             0.00   0.07   0.00      0.00
# 43_eisenhower_1957             0.00   0.07   0.00      0.00
# 44_kennedy_1961                0.00   0.01   0.00      0.00
# 45_johnson_1965                0.02   0.03   0.00      0.05
# 46_nixon_1969                  0.00   0.01   0.00      0.00
# 47_nixon_1973                  0.00   0.00   0.00      0.02
# 48_carter_1977                 0.02   0.00   0.00      0.00
# 49_reagan_1981                 0.00   0.02   0.04      0.09
# 50_reagan_1985                 0.00   0.03   0.04      0.00
# 51_bush_george_h_w_1989        0.01   0.04   0.06      0.07
# 52_clinton_1993                0.02   0.01   0.02      0.06
# 53_clinton_1997                0.00   0.00   0.02      0.10
# 54_bush_george_w_2001          0.00   0.00   0.00      0.08
# 55_bush_george_w_2005          0.00   0.02   0.04      0.00
# 56_obama_2009                  0.00   0.04   0.08      0.05
# 57_obama_2013                  0.00   0.04   0.04      0.06
# 58_trump_2017                  0.05   0.03   0.05      0.04

# %% [markdown]
# Let's drop "OO_Document Frequency" since we were just using it for illustration purposes.

# %%
tfidf_df = tfidf_df.drop('00_Document Frequency', errors='ignore')

# %% [markdown]
# Let's reorganize the DataFrame so that the words are in rows rather than columns.

# %%
tfidf_df.stack().reset_index()
# Out:
#                  level_0    level_1         0
# 0       26_harrison_1889        000  0.000000
# 1       26_harrison_1889         03  0.010027
# 2       26_harrison_1889         04  0.010236
# 3       26_harrison_1889         05  0.000000
# 4       26_harrison_1889        100  0.000000
# ...                  ...        ...       ...
# 521937    41_truman_1949    zachary  0.000000
# 521938    41_truman_1949       zeal  0.000000
# 521939    41_truman_1949    zealous  0.000000
# 521940    41_truman_1949  zealously  0.000000
# 521941    41_truman_1949       zone  0.000000
#
# [521942 rows x 3 columns]

# %%
tfidf_df = tfidf_df.stack().reset_index()

# %%
tfidf_df = tfidf_df.rename(columns={0:'tfidf', 'level_0': 'document','level_1': 'term', 'level_2': 'term'})

# %% [markdown]
# To find out the top 10 words with the highest tf–idf for every story, we're going to sort by document and tfidf score and then groupby document and take the first 10 values.

# %%
tfidf_df.sort_values(by=['document','tfidf'], ascending=[True,False]).groupby(['document']).head(10)
# Out:
#                           document            term     tfidf
# 174688          01_washington_1789      government  0.113681
# 175089          01_washington_1789       immutable  0.103883
# 175156          01_washington_1789     impressions  0.103883
# 177318          01_washington_1789    providential  0.103883
# 176612          01_washington_1789           ought  0.103728
# 177332          01_washington_1789          public  0.103102
# 177098          01_washington_1789         present  0.097516
# 177370          01_washington_1789  qualifications  0.096372
# 176792          01_washington_1789      peculiarly  0.090546
# 171634          01_washington_1789         article  0.085786
# 63012           02_washington_1793            1793  0.229350
# 63637           02_washington_1793          arrive  0.229350
# 71570           02_washington_1793     upbraidings  0.229350
# 67244           02_washington_1793       incurring  0.208140
# 71694           02_washington_1793        violated  0.208140
# 71866           02_washington_1793       willingly  0.208140
# 67362           02_washington_1793     injunctions  0.193091
# 67699           02_washington_1793       knowingly  0.193091
# 69151           02_washington_1793        previous  0.193091
# 71904           02_washington_1793       witnesses  0.193091
# 284792          03_adams_john_1797          people  0.191180
# 282676          03_adams_john_1797      government  0.160937
# 284930          03_adams_john_1797        pleasing  0.147066
# 282433          03_adams_john_1797         foreign  0.116874
# 284327          03_adams_john_1797         nations  0.114480
# 287682          03_adams_john_1797        virtuous  0.110813
# 282987          03_adams_john_1797          houses  0.110300
# 283770          03_adams_john_1797    legislatures  0.110300
# 280730          03_adams_john_1797    constitution  0.104525
# 282954          03_adams_john_1797           honor  0.102265
# 30704            04_jefferson_1801      government  0.155691
# 33171            04_jefferson_1801       principle  0.130113
# 31814            04_jefferson_1801             let  0.117970
# 34063            04_jefferson_1801          safety  0.108427
# 32010            04_jefferson_1801             man  0.106841
# 35095            04_jefferson_1801      thousandth  0.104513
# 30979            04_jefferson_1801          honest  0.101696
# 30327            04_jefferson_1801          fellow  0.097240
# 33893            04_jefferson_1801          retire  0.094848
# 32574            04_jefferson_1801         opinion  0.092587
# 51346            05_jefferson_1805          public  0.180456
# 48256            05_jefferson_1805           false  0.135863
# 52617            05_jefferson_1805           state  0.121514
# 53835            05_jefferson_1805      whatsoever  0.116886
# 49871            05_jefferson_1805          limits  0.107085
# 46367            05_jefferson_1805        citizens  0.106592
# 51485            05_jefferson_1805          reason  0.104438
# 46480            05_jefferson_1805        comforts  0.101880
# 51130            05_jefferson_1805           press  0.101549
# 48137            05_jefferson_1805        expenses  0.096524
# 310150             06_madison_1809    improvements  0.152559
# 306894             06_madison_1809     belligerent  0.123161
# 312317             06_madison_1809          public  0.122235
# 311324             06_madison_1809         nations  0.104588
# 312699             06_madison_1809        rendered  0.101706
# 306753             06_madison_1809     authorities  0.089155
# 306764             06_madison_1809           avail  0.089155
# 309012             06_madison_1809        examples  0.089155
# 307869             06_madison_1809        councils  0.085894
# 311529             06_madison_1809            ones  0.085894
# 206743             07_madison_1813             war  0.254249
# 199085             07_madison_1813         british  0.222972
# 203046             07_madison_1813        massacre  0.119009
# 199188             07_madison_1813        captives  0.108003
# 199960             07_madison_1813           cruel  0.108003
# 204159             07_madison_1813       prisoners  0.108003
# 205080             07_madison_1813          savage  0.108003
# 200724             07_madison_1813         element  0.085005
# 200825             07_madison_1813           enemy  0.085005
# 201964             07_madison_1813       honorable  0.084762
# 358588              08_monroe_1817          states  0.184195
# 354668              08_monroe_1817      government  0.174125
# 354702              08_monroe_1817           great  0.160658
# 359430              08_monroe_1817           union  0.117193
# 356784              08_monroe_1817          people  0.112825
# 359433              08_monroe_1817          united  0.112076
# 352994              08_monroe_1817         dangers  0.108567
# 356328              08_monroe_1817           naval  0.104713
# 354425              08_monroe_1817         foreign  0.103460
# 357136              08_monroe_1817      principles  0.097766
# 147725              09_monroe_1821           great  0.173751
# 151611              09_monroe_1821          states  0.137384
# 150901              09_monroe_1821         revenue  0.115018
# 152749              09_monroe_1821             war  0.113785
# 149734              09_monroe_1821         parties  0.109318
# 152456              09_monroe_1821          united  0.108029
# 145488              09_monroe_1821        commerce  0.105001
# 147436              09_monroe_1821           force  0.102947
# 147482              09_monroe_1821  fortifications  0.098741
# 152018              09_monroe_1821            term  0.094808
# 332433   10_adams_john_quincy_1825           union  0.257335
# 327671   10_adams_john_quincy_1825      government  0.147726
# 327606   10_adams_john_quincy_1825         general  0.109221
# 330933   10_adams_john_quincy_1825          rights  0.096300
# 326482   10_adams_john_quincy_1825     dissensions  0.095289
# 330315   10_adams_john_quincy_1825          public  0.094573
# 325725   10_adams_john_quincy_1825    constitution  0.090300
# 329765   10_adams_john_quincy_1825           peace  0.088183
# 325882   10_adams_john_quincy_1825         country  0.086898
# 329802   10_adams_john_quincy_1825     performance  0.085565
# 213328             11_jackson_1829          public  0.160747
# 210620             11_jackson_1829       generally  0.122711
# 209358             11_jackson_1829      diffidence  0.112691
# 209117             11_jackson_1829       defending  0.105878
# 214259             11_jackson_1829           shall  0.104933
# 213894             11_jackson_1829         revenue  0.102776
# 215925             11_jackson_1829           worth  0.100312
# 210684             11_jackson_1829      government  0.099698
# 210293             11_jackson_1829         federal  0.093100
# 213021             11_jackson_1829           power  0.092071
# 296437             12_jackson_1833           union  0.212766
# 291675             12_jackson_1833      government  0.207559
# 295595             12_jackson_1833          states  0.141549
# 293791             12_jackson_1833          people  0.136557
# 294091             12_jackson_1833    preservation  0.128319
# 291610             12_jackson_1833         general  0.125422
# 291060             12_jackson_1833        exercise  0.119275
# 292213             12_jackson_1833       inculcate  0.116720
# 294262             12_jackson_1833      proportion  0.116720
# 294015             12_jackson_1833          powers  0.113757
# 121414           13_van_buren_1837    institutions  0.186889
# 122810           13_van_buren_1837          people  0.138465
# 120694           13_van_buren_1837      government  0.116561
# 124859           13_van_buren_1837        supposed  0.109949
# 118905           13_van_buren_1837         country  0.109276
# 117230           13_van_buren_1837          actual  0.096382
# 120131           13_van_buren_1837      experience  0.093444
# 117254           13_van_buren_1837       adherence  0.083833
# 118626           13_van_buren_1837         conduct  0.081635
# 122565           13_van_buren_1837        opinions  0.081597
# 24042             14_harrison_1841           power  0.204207
# 19759             14_harrison_1841    constitution  0.183336
# 21084             14_harrison_1841       executive  0.157153
# 23821             14_harrison_1841          people  0.141584
# 21705             14_harrison_1841      government  0.141142
# 25011             14_harrison_1841           roman  0.110538
# 25625             14_harrison_1841          states  0.108621
# 19370             14_harrison_1841        citizens  0.105857
# 19303             14_harrison_1841       character  0.102640
# 25620             14_harrison_1841           state  0.094976
# 188449                15_polk_1845           union  0.259054
# 183687                15_polk_1845      government  0.256967
# 187607                15_polk_1845          states  0.218122
# 188035                15_polk_1845           texas  0.199846
# 186897                15_polk_1845         revenue  0.146541
# 186027                15_polk_1845          powers  0.124655
# 186301                15_polk_1845      protection  0.107385
# 181741                15_polk_1845    constitution  0.106528
# 184457                15_polk_1845       interests  0.105054
# 183163                15_polk_1845        extended  0.090179
# 457232              16_taylor_1849           shall  0.266204
# 453657              16_taylor_1849      government  0.118031
# 452614              16_taylor_1849          duties  0.117893
# 455422              16_taylor_1849          object  0.104293
# 451640              16_taylor_1849        congress  0.103865
# 456318              16_taylor_1849          purity  0.101793
# 458616              16_taylor_1849          vested  0.101793
# 455056              16_taylor_1849        measures  0.101637
# 451868              16_taylor_1849         country  0.101169
# 450287              16_taylor_1849      affections  0.097017
# 363801              17_pierce_1853          hardly  0.114001
# 366004              17_pierce_1853           power  0.102456
# 365975              17_pierce_1853        position  0.086643
# 361722              17_pierce_1853  constitutional  0.086105
# 363087              17_pierce_1853          expect  0.084436
# 363667              17_pierce_1853      government  0.084048
# 360502              17_pierce_1853        apparent  0.080332
# 366585              17_pierce_1853        regarded  0.080332
# 367242              17_pierce_1853           shall  0.079615
# 364823              17_pierce_1853            like  0.079229
# 79619             18_buchanan_1857          states  0.208199
# 73753             18_buchanan_1857    constitution  0.188573
# 79274             18_buchanan_1857           shall  0.161784
# 78390             18_buchanan_1857        question  0.157007
# 80836             18_buchanan_1857          whilst  0.141119
# 80037             18_buchanan_1857       territory  0.140852
# 80461             18_buchanan_1857           union  0.126444
# 75699             18_buchanan_1857      government  0.119554
# 73682             18_buchanan_1857        congress  0.118357
# 77815             18_buchanan_1857          people  0.105501
# 433713             19_lincoln_1861    constitution  0.214478
# 440421             19_lincoln_1861           union  0.203738
# 433185             19_lincoln_1861            case  0.152422
# 439579             19_lincoln_1861          states  0.144861
# 437156             19_lincoln_1861        minority  0.131514
# 437775             19_lincoln_1861          people  0.130763
# 433347             19_lincoln_1861          clause  0.125738
# 435659             19_lincoln_1861      government  0.123837
# 439234             19_lincoln_1861           shall  0.123099
# 436710             19_lincoln_1861             law  0.122872
# 467714             20_lincoln_1865             war  0.267217
# 464484             20_lincoln_1865        offenses  0.234524
# 467862             20_lincoln_1865             woe  0.234524
# 462640             20_lincoln_1865             god  0.151269
# 464483             20_lincoln_1865         offense  0.141890
# 467824             20_lincoln_1865           wills  0.141890
# 459460             20_lincoln_1865        answered  0.131631
# 466364             20_lincoln_1865          slaves  0.123674
# 467418             20_lincoln_1865           union  0.114955
# 459394             20_lincoln_1865      altogether  0.111675
# 398548               21_grant_1869          dollar  0.270439
# 401752               21_grant_1869          paying  0.162263
# 398011               21_grant_1869            deal  0.152454
# 403483               21_grant_1869          specie  0.152454
# 398026               21_grant_1869            debt  0.135097
# 397874               21_grant_1869         country  0.127604
# 396278               21_grant_1869       advisable  0.116606
# 400721               21_grant_1869            laws  0.115834
# 401754               21_grant_1869        payments  0.108175
# 401750               21_grant_1869             pay  0.098658
# 447253               22_grant_1873     proposition  0.187222
# 443554               22_grant_1873         domingo  0.177516
# 448042               22_grant_1873           santo  0.177516
# 449177               22_grant_1873         transit  0.177516
# 448996               22_grant_1873       territory  0.121158
# 444144               22_grant_1873   extermination  0.118344
# 448601               22_grant_1873           steam  0.118344
# 448953               22_grant_1873       telegraph  0.118344
# 442869               22_grant_1873         country  0.117529
# 444137               22_grant_1873       extension  0.116618
# 415872               23_hayes_1877         country  0.186357
# 417661               23_hayes_1877      government  0.167722
# 414866               23_hayes_1877          behalf  0.128316
# 420305               23_hayes_1877          public  0.123944
# 419942               23_hayes_1877       political  0.121034
# 421581               23_hayes_1877          states  0.113587
# 419711               23_hayes_1877           party  0.112549
# 416459               23_hayes_1877         dispute  0.112503
# 419704               23_hayes_1877         parties  0.109554
# 420559               23_hayes_1877          reform  0.104365
# 129693            24_garfield_1881      government  0.186855
# 131809            24_garfield_1881          people  0.162132
# 127747            24_garfield_1881    constitution  0.158292
# 133613            24_garfield_1881          states  0.135047
# 134455            24_garfield_1881           union  0.132321
# 133796            24_garfield_1881        suffrage  0.119992
# 131386            24_garfield_1881           negro  0.118782
# 126774            24_garfield_1881       authority  0.117232
# 127676            24_garfield_1881        congress  0.112598
# 130744            24_garfield_1881             law  0.103639
# 275793           25_cleveland_1885          people  0.210468
# 273677           25_cleveland_1885      government  0.209164
# 275721           25_cleveland_1885        partisan  0.169436
# 276321           25_cleveland_1885          public  0.163662
# 277252           25_cleveland_1885           shall  0.129498
# 271731           25_cleveland_1885    constitution  0.127856
# 274447           25_cleveland_1885       interests  0.118207
# 273174           25_cleveland_1885    extravagance  0.111416
# 271340           25_cleveland_1885         citizen  0.102825
# 277685           25_cleveland_1885          strife  0.101661
# 5823              26_harrison_1889          people  0.172358
# 4765              26_harrison_1889            laws  0.154418
# 7627              26_harrison_1889          states  0.138614
# 846               26_harrison_1889          ballot  0.137159
# 6351              26_harrison_1889          public  0.128566
# 5161              26_harrison_1889         methods  0.119162
# 7282              26_harrison_1889           shall  0.118483
# 3569              26_harrison_1889        friendly  0.104267
# 3010              26_harrison_1889        european  0.103349
# 1761              26_harrison_1889    constitution  0.089360
# 59817            27_cleveland_1893          people  0.221563
# 57701            27_cleveland_1893      government  0.148364
# 57576            27_cleveland_1893       frugality  0.128050
# 60345            27_cleveland_1893          public  0.102520
# 61246            27_cleveland_1893         service  0.101813
# 61860            27_cleveland_1893         support  0.099946
# 54456            27_cleveland_1893        american  0.097267
# 54235            27_cleveland_1893        activity  0.095964
# 57702            27_cleveland_1893    governmental  0.095964
# 55913            27_cleveland_1893      countrymen  0.088564
# 235664            28_mckinley_1897        congress  0.188773
# 240891            28_mckinley_1897         revenue  0.168489
# 239797            28_mckinley_1897          people  0.161797
# 237681            28_mckinley_1897      government  0.156633
# 238873            28_mckinley_1897           loans  0.149356
# 238771            28_mckinley_1897     legislation  0.126367
# 240325            28_mckinley_1897          public  0.107057
# 235128            28_mckinley_1897        business  0.106759
# 237715            28_mckinley_1897           great  0.105322
# 240905            28_mckinley_1897        revision  0.099571
# 256568            29_mckinley_1901         islands  0.216480
# 253961            29_mckinley_1901            cuba  0.206329
# 255679            29_mckinley_1901      government  0.153681
# 255058            29_mckinley_1901       executive  0.147843
# 256326            29_mckinley_1901     inhabitants  0.147374
# 253662            29_mckinley_1901        congress  0.141999
# 257795            29_mckinley_1901          people  0.116839
# 259599            29_mckinley_1901          states  0.102186
# 260444            29_mckinley_1901          united  0.100439
# 258071            29_mckinley_1901     preparation  0.097925
# 87619   30_roosevelt_theodore_1905         regards  0.199163
# 87186   30_roosevelt_theodore_1905        problems  0.182463
# 88967   30_roosevelt_theodore_1905           tasks  0.150068
# 81609   30_roosevelt_theodore_1905          aright  0.146306
# 87774   30_roosevelt_theodore_1905        republic  0.121428
# 85837   30_roosevelt_theodore_1905            life  0.118701
# 82239   30_roosevelt_theodore_1905           cause  0.116483
# 84208   30_roosevelt_theodore_1905           faced  0.115730
# 82628   30_roosevelt_theodore_1905      conditions  0.115373
# 89886   30_roosevelt_theodore_1905            wish  0.106771
# 94491                 31_taft_1909      interstate  0.206957
# 91144                 31_taft_1909        business  0.201378
# 97960                 31_taft_1909          tariff  0.154802
# 95390                 31_taft_1909           negro  0.153669
# 97489                 31_taft_1909           south  0.129384
# 93697                 31_taft_1909      government  0.121451
# 96276                 31_taft_1909          proper  0.114684
# 96401                 31_taft_1909            race  0.113413
# 93312                 31_taft_1909         feeling  0.111255
# 91176                 31_taft_1909           canal  0.110879
# 345703              32_wilson_1913           great  0.158659
# 347093              32_wilson_1913             men  0.142924
# 345229              32_wilson_1913        familiar  0.141669
# 349635              32_wilson_1913         stirred  0.141669
# 349702              32_wilson_1913         studied  0.141669
# 350039              32_wilson_1913          things  0.123915
# 346628              32_wilson_1913         justice  0.105759
# 345669              32_wilson_1913      government  0.105520
# 346808              32_wilson_1913            life  0.102168
# 346885              32_wilson_1913            look  0.100095
# 503841              33_wilson_1917          wished  0.228593
# 496849              33_wilson_1917         counsel  0.174639
# 501316              33_wilson_1917         purpose  0.152933
# 495180              33_wilson_1917          action  0.149960
# 502227              33_wilson_1917           shall  0.134404
# 503036              33_wilson_1917         thought  0.126568
# 502554              33_wilson_1917           stand  0.121313
# 502204              33_wilson_1917             set  0.111215
# 500937              33_wilson_1917        politics  0.108510
# 497582              33_wilson_1917           drawn  0.104783
# 143923             34_harding_1921           world  0.196268
# 136364             34_harding_1921    civilization  0.157095
# 135446             34_harding_1921         america  0.155684
# 143750             34_harding_1921             war  0.120631
# 141657             34_harding_1921    relationship  0.118846
# 141768             34_harding_1921        republic  0.117160
# 140590             34_harding_1921           order  0.110128
# 143374             34_harding_1921   understanding  0.109915
# 140398             34_harding_1921             new  0.097567
# 135454             34_harding_1921            amid  0.095077
# 469866            35_coolidge_1925         country  0.120814
# 473579            35_coolidge_1925           ought  0.116721
# 474727            35_coolidge_1925      represents  0.114495
# 475927            35_coolidge_1925             tax  0.112826
# 471689            35_coolidge_1925           great  0.109908
# 474236            35_coolidge_1925        property  0.108285
# 473705            35_coolidge_1925           party  0.107300
# 475562            35_coolidge_1925          stands  0.107257
# 473749            35_coolidge_1925           peace  0.104170
# 473771            35_coolidge_1925          people  0.101306
# 250815              36_hoover_1929             sup  0.296865
# 246680              36_hoover_1929      government  0.202690
# 245829              36_hoover_1929     enforcement  0.194371
# 243033              36_hoover_1929            18th  0.134706
# 249215              36_hoover_1929        progress  0.132406
# 246289              36_hoover_1929         federal  0.126183
# 247034              36_hoover_1929          ideals  0.113418
# 244127              36_hoover_1929        business  0.108323
# 247738              36_hoover_1929            laws  0.107051
# 248774              36_hoover_1929           peace  0.103883
# 507871  37_roosevelt_franklin_1933          helped  0.215644
# 508716  37_roosevelt_franklin_1933      leadership  0.191084
# 511653  37_roosevelt_franklin_1933        stricken  0.129390
# 506724  37_roosevelt_franklin_1933       emergency  0.123225
# 506381  37_roosevelt_franklin_1933      discipline  0.117971
# 510786  37_roosevelt_franklin_1933        respects  0.117971
# 509215  37_roosevelt_franklin_1933           money  0.113371
# 509298  37_roosevelt_franklin_1933        national  0.110570
# 510502  37_roosevelt_franklin_1933        recovery  0.102349
# 504179  37_roosevelt_franklin_1933          action  0.097007
# 110197  38_roosevelt_franklin_1937       democracy  0.178041
# 111695  38_roosevelt_franklin_1937      government  0.177222
# 113171  38_roosevelt_franklin_1937        millions  0.140722
# 113696  38_roosevelt_franklin_1937           paint  0.121461
# 113811  38_roosevelt_franklin_1937          people  0.115789
# 110689  38_roosevelt_franklin_1937        economic  0.114184
# 114979  38_roosevelt_franklin_1937            road  0.112944
# 114230  38_roosevelt_franklin_1937        progress  0.104463
# 110280  38_roosevelt_franklin_1937         despair  0.100302
# 113341  38_roosevelt_franklin_1937          nation  0.099688
# 317174  39_roosevelt_franklin_1941       democracy  0.244486
# 319669  39_roosevelt_franklin_1941            know  0.189060
# 322489  39_roosevelt_franklin_1941          speaks  0.183385
# 316035  39_roosevelt_franklin_1941              br  0.163241
# 320318  39_roosevelt_franklin_1941          nation  0.162241
# 315426  39_roosevelt_franklin_1941         america  0.140133
# 319811  39_roosevelt_franklin_1941            life  0.117815
# 322520  39_roosevelt_franklin_1941          spirit  0.114445
# 318516  39_roosevelt_franklin_1941         freedom  0.109295
# 315038  39_roosevelt_franklin_1941            1941  0.108911
# 337740  40_roosevelt_franklin_1945         learned  0.300396
# 341012  40_roosevelt_franklin_1945            test  0.194731
# 333037  40_roosevelt_franklin_1945            1945  0.189849
# 340245  40_roosevelt_franklin_1945           shall  0.173637
# 341226  40_roosevelt_franklin_1945           trend  0.172292
# 338199  40_roosevelt_franklin_1945        mistakes  0.159835
# 338764  40_roosevelt_franklin_1945           peace  0.159442
# 341111  40_roosevelt_franklin_1945           today  0.154299
# 341553  40_roosevelt_franklin_1945          upward  0.150172
# 336584  40_roosevelt_franklin_1945            gain  0.142278
# 521881              41_truman_1949           world  0.196051
# 518301              41_truman_1949         nations  0.194029
# 519183              41_truman_1949         program  0.171656
# 518767              41_truman_1949         peoples  0.166989
# 515152              41_truman_1949       democracy  0.154140
# 516494              41_truman_1949         freedom  0.149297
# 514471              41_truman_1949       communism  0.147134
# 518744              41_truman_1949           peace  0.144167
# 514860              41_truman_1949       countries  0.137013
# 519501              41_truman_1949        recovery  0.135785
# 102537          42_eisenhower_1953            free  0.205803
# 102239          42_eisenhower_1953           faith  0.154561
# 107927          42_eisenhower_1953           world  0.146449
# 104813          42_eisenhower_1953         peoples  0.139466
# 105212          42_eisenhower_1953    productivity  0.133826
# 106688          42_eisenhower_1953        strength  0.130430
# 104790          42_eisenhower_1953           peace  0.123845
# 102540          42_eisenhower_1953         freedom  0.123320
# 106271          42_eisenhower_1953           shall  0.105970
# 102959          42_eisenhower_1953            hold  0.105028
# 197917          43_eisenhower_1957           world  0.193893
# 192530          43_eisenhower_1957         freedom  0.179599
# 196175          43_eisenhower_1957            seek  0.176008
# 194337          43_eisenhower_1957         nations  0.175538
# 194803          43_eisenhower_1957         peoples  0.158270
# 196702          43_eisenhower_1957         strives  0.146428
# 194780          43_eisenhower_1957           peace  0.136639
# 192905          43_eisenhower_1957            help  0.132688
# 191547          43_eisenhower_1957         divided  0.115450
# 194294          43_eisenhower_1957              mr  0.111886
# 265788             44_kennedy_1961             let  0.267869
# 268320             44_kennedy_1961           sides  0.262849
# 266935             44_kennedy_1961          pledge  0.160960
# 261646             44_kennedy_1961             ask  0.107713
# 261878             44_kennedy_1961           begin  0.106495
# 263005             44_kennedy_1961            dare  0.106495
# 269909             44_kennedy_1961           world  0.103110
# 264327             44_kennedy_1961           final  0.102311
# 266384             44_kennedy_1961             new  0.096600
# 264134             44_kennedy_1961         explore  0.094223
# 406250             45_johnson_1965          change  0.276090
# 406886             45_johnson_1965        covenant  0.242891
# 409968             45_johnson_1965             man  0.174391
# 410030             45_johnson_1965         mastery  0.153532
# 410308             45_johnson_1965          nation  0.152475
# 413424             45_johnson_1965           union  0.150512
# 410507             45_johnson_1965             old  0.129184
# 413266             45_johnson_1965          trying  0.109663
# 410778             45_johnson_1965          people  0.108677
# 408813             45_johnson_1965         harvest  0.102355
# 161710               46_nixon_1969          voices  0.208854
# 158784               46_nixon_1969           peace  0.144624
# 157800               46_nixon_1969             let  0.140977
# 155669               46_nixon_1969           earth  0.139513
# 157687               46_nixon_1969            know  0.137969
# 157996               46_nixon_1969             man  0.135416
# 158806               46_nixon_1969          people  0.131270
# 161921               46_nixon_1969           world  0.128264
# 159929               46_nixon_1969        rhetoric  0.119219
# 156495               46_nixon_1969         forward  0.113215
# 36457                47_nixon_1973         america  0.307074
# 40813                47_nixon_1973             let  0.282212
# 41797                47_nixon_1973           peace  0.211567
# 43005                47_nixon_1973            role  0.190395
# 44934                47_nixon_1973           world  0.177760
# 41980                47_nixon_1973        policies  0.176224
# 42845                47_nixon_1973  responsibility  0.164016
# 41409                47_nixon_1973             new  0.158606
# 36144                47_nixon_1973          abroad  0.154815
# 39974                47_nixon_1973            home  0.126653
# 217046              48_carter_1977              br  0.222574
# 221329              48_carter_1977          nation  0.191717
# 218616              48_carter_1977           dream  0.181515
# 223675              48_carter_1977        strength  0.147104
# 221389              48_carter_1977             new  0.142111
# 221140              48_carter_1977           micah  0.118797
# 224037              48_carter_1977            thee  0.107811
# 223531              48_carter_1977          spirit  0.107000
# 219998              48_carter_1977           human  0.101203
# 218850              48_carter_1977         enhance  0.100016
# 480654              49_reagan_1981      government  0.162397
# 477411              49_reagan_1981       americans  0.156895
# 480889              49_reagan_1981          heroes  0.137410
# 477868              49_reagan_1981         believe  0.136126
# 485600              49_reagan_1981              ve  0.115339
# 483170              49_reagan_1981    productivity  0.104753
# 485765              49_reagan_1981          weapon  0.104753
# 480498              49_reagan_1981         freedom  0.102964
# 479589              49_reagan_1981          dreams  0.101106
# 485095              49_reagan_1981           today  0.093813
# 381665              50_reagan_1985      government  0.161165
# 381509              50_reagan_1985         freedom  0.159998
# 383412              50_reagan_1985         nuclear  0.153623
# 386611              50_reagan_1985              ve  0.153623
# 386777              50_reagan_1985         weapons  0.140173
# 383781              50_reagan_1985          people  0.137038
# 386896              50_reagan_1985           world  0.127236
# 381923              50_reagan_1985         history  0.104777
# 381980              50_reagan_1985           human  0.104777
# 385179              50_reagan_1985         senator  0.102416
# 389563     51_bush_george_h_w_1989             don  0.186313
# 388045     51_bush_george_h_w_1989          breeze  0.184416
# 392370     51_bush_george_h_w_1989             new  0.137266
# 390527     51_bush_george_h_w_1989         friends  0.136820
# 389567     51_bush_george_h_w_1989            door  0.133889
# 395882     51_bush_george_h_w_1989            word  0.131722
# 392272     51_bush_george_h_w_1989              mr  0.126821
# 390770     51_bush_george_h_w_1989            hand  0.125086
# 387975     51_bush_george_h_w_1989         blowing  0.110649
# 395034     51_bush_george_h_w_1989          things  0.110609
# 162443             52_clinton_1993         america  0.318908
# 170920             52_clinton_1993           world  0.226715
# 162446             52_clinton_1993       americans  0.206865
# 170130             52_clinton_1993           today  0.185539
# 163277             52_clinton_1993          change  0.170522
# 168719             52_clinton_1993         renewal  0.136867
# 169145             52_clinton_1993          season  0.136867
# 166038             52_clinton_1993            idea  0.134993
# 166799             52_clinton_1993             let  0.132521
# 167805             52_clinton_1993          people  0.129272
# 298243             53_clinton_1997         century  0.321300
# 302380             53_clinton_1997             new  0.279600
# 297428             53_clinton_1997         america  0.199997
# 303227             53_clinton_1997         promise  0.164327
# 305905             53_clinton_1997           world  0.135071
# 301694             53_clinton_1997            land  0.131027
# 302320             53_clinton_1997          nation  0.117062
# 297431             53_clinton_1997       americans  0.115029
# 305101             53_clinton_1997            time  0.108057
# 301784             53_clinton_1997             let  0.105270
# 16685        54_bush_george_w_2001           story  0.341166
# 9460         54_bush_george_w_2001         america  0.193152
# 10377        54_bush_george_w_2001        civility  0.160853
# 14352        54_bush_george_w_2001          nation  0.130448
# 9338         54_bush_george_w_2001          affirm  0.120640
# 13060        54_bush_george_w_2001          ideals  0.109491
# 9463         54_bush_george_w_2001       americans  0.108207
# 15259        54_bush_george_w_2001         promise  0.108207
# 10543        54_bush_george_w_2001      compassion  0.107388
# 10371        54_bush_george_w_2001        citizens  0.106730
# 426504       55_bush_george_w_2005         freedom  0.349948
# 423414       55_bush_george_w_2005         america  0.284882
# 427793       55_bush_george_w_2005         liberty  0.174494
# 423417       55_bush_george_w_2005       americans  0.140443
# 431279       55_bush_george_w_2005         tyranny  0.127272
# 430155       55_bush_george_w_2005            seen  0.110386
# 428306       55_bush_george_w_2005          nation  0.096199
# 424201       55_bush_george_w_2005           cause  0.092545
# 426918       55_bush_george_w_2005         history  0.092422
# 424133       55_bush_george_w_2005            came  0.091988
# 225436               56_obama_2009         america  0.148351
# 230328               56_obama_2009          nation  0.120229
# 230388               56_obama_2009             new  0.118002
# 233123               56_obama_2009           today  0.114792
# 228620               56_obama_2009      generation  0.100654
# 229792               56_obama_2009             let  0.091100
# 229608               56_obama_2009            jobs  0.090727
# 226941               56_obama_2009          crisis  0.087235
# 228809               56_obama_2009            hard  0.084859
# 233891               56_obama_2009           women  0.084859
# 373600               57_obama_2013         journey  0.167591
# 370914               57_obama_2013           creed  0.139659
# 372604               57_obama_2013      generation  0.127260
# 369420               57_obama_2013         america  0.125044
# 370524               57_obama_2013        complete  0.114891
# 375756               57_obama_2013        requires  0.114891
# 374782               57_obama_2013          people  0.110351
# 377093               57_obama_2013            time  0.105563
# 377107               57_obama_2013           today  0.103668
# 371985               57_obama_2013         evident  0.100896
# 486407               58_trump_2017         america  0.350162
# 488588               58_trump_2017          dreams  0.156436
# 486408               58_trump_2017        american  0.149226
# 490579               58_trump_2017            jobs  0.142766
# 492265               58_trump_2017       protected  0.132439
# 491412               58_trump_2017           obama  0.120288
# 491769               58_trump_2017          people  0.112370
# 494004               58_trump_2017           thank  0.109171
# 486992               58_trump_2017         borders  0.107075
# 494599               58_trump_2017              ve  0.107075

# %%
top_tfidf = tfidf_df.sort_values(by=['document','tfidf'], ascending=[True,False]).groupby(['document']).head(10)

# %% [markdown]
# We can zoom in on particular words and particular documents.

# %%
top_tfidf[top_tfidf['term'].str.contains('women')]
# Out:
#              document   term     tfidf
# 233891  56_obama_2009  women  0.084859

# %% [markdown]
# It turns out that the term "women" is very distinctive in Obama's Inaugural Address.

# %%
top_tfidf[top_tfidf['document'].str.contains('obama')]
# Out:
#              document        term     tfidf
# 225436  56_obama_2009     america  0.148351
# 230328  56_obama_2009      nation  0.120229
# 230388  56_obama_2009         new  0.118002
# 233123  56_obama_2009       today  0.114792
# 228620  56_obama_2009  generation  0.100654
# 229792  56_obama_2009         let  0.091100
# 229608  56_obama_2009        jobs  0.090727
# 226941  56_obama_2009      crisis  0.087235
# 228809  56_obama_2009        hard  0.084859
# 233891  56_obama_2009       women  0.084859
# 373600  57_obama_2013     journey  0.167591
# 370914  57_obama_2013       creed  0.139659
# 372604  57_obama_2013  generation  0.127260
# 369420  57_obama_2013     america  0.125044
# 370524  57_obama_2013    complete  0.114891
# 375756  57_obama_2013    requires  0.114891
# 374782  57_obama_2013      people  0.110351
# 377093  57_obama_2013        time  0.105563
# 377107  57_obama_2013       today  0.103668
# 371985  57_obama_2013     evident  0.100896

# %%
top_tfidf[top_tfidf['document'].str.contains('trump')]
# Out:
#              document       term     tfidf
# 486407  58_trump_2017    america  0.350162
# 488588  58_trump_2017     dreams  0.156436
# 486408  58_trump_2017   american  0.149226
# 490579  58_trump_2017       jobs  0.142766
# 492265  58_trump_2017  protected  0.132439
# 491412  58_trump_2017      obama  0.120288
# 491769  58_trump_2017     people  0.112370
# 494004  58_trump_2017      thank  0.109171
# 486992  58_trump_2017    borders  0.107075
# 494599  58_trump_2017         ve  0.107075

# %%
top_tfidf[top_tfidf['document'].str.contains('kennedy')]
# Out:
#                document     term     tfidf
# 265788  44_kennedy_1961      let  0.267869
# 268320  44_kennedy_1961    sides  0.262849
# 266935  44_kennedy_1961   pledge  0.160960
# 261646  44_kennedy_1961      ask  0.107713
# 261878  44_kennedy_1961    begin  0.106495
# 263005  44_kennedy_1961     dare  0.106495
# 269909  44_kennedy_1961    world  0.103110
# 264327  44_kennedy_1961    final  0.102311
# 266384  44_kennedy_1961      new  0.096600
# 264134  44_kennedy_1961  explore  0.094223

# %% [markdown]
# ## Visualize TF-IDF

# %% [markdown]
# We can also visualize our TF-IDF results with the data visualization library Altair.

# %%
# !pip install altair

# %% [markdown]
# Let's make a heatmap that shows the highest TF-IDF scoring words for each president, and let's put a red dot next to two terms of interest: "war" and "peace":
#
# The code below was contributed by [Eric Monson](https://github.com/emonson). Thanks, Eric!

# %%
import altair as alt
import numpy as np

# Terms in this list will get a red dot in the visualization
term_list = ['war', 'peace']

# adding a little randomness to break ties in term ranking
top_tfidf_plusRand = top_tfidf.copy()
top_tfidf_plusRand['tfidf'] = top_tfidf_plusRand['tfidf'] + np.random.rand(top_tfidf.shape[0])*0.0001

# base for all visualizations, with rank calculation
base = alt.Chart(top_tfidf_plusRand).encode(
    x = 'rank:O',
    y = 'document:N'
).transform_window(
    rank = "rank()",
    sort = [alt.SortField("tfidf", order="descending")],
    groupby = ["document"],
)

# heatmap specification
heatmap = base.mark_rect().encode(
    color = 'tfidf:Q'
)

# red circle over terms in above list
circle = base.mark_circle(size=100).encode(
    color = alt.condition(
        alt.FieldOneOfPredicate(field='term', oneOf=term_list),
        alt.value('red'),
        alt.value('#FFFFFF00')
    )
)

# text labels, white for darker heatmap colors
text = base.mark_text(baseline='middle').encode(
    text = 'term:N',
    color = alt.condition(alt.datum.tfidf >= 0.23, alt.value('white'), alt.value('black'))
)

# display the three superimposed visualizations
(heatmap + circle + text).properties(width = 600)
# Out:
# /usr/local/lib/python3.10/dist-packages/altair/utils/core.py:384: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /usr/local/lib/python3.10/dist-packages/altair/utils/core.py:384: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.LayerChart(...)
